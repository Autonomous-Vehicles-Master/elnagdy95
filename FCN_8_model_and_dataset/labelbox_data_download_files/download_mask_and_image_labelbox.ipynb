# %%
# make sure that the exported JSON file and this script are in the same directory
# replace filename with appropriate
from PIL import Image
import requests, urllib, json, os, csv, sys
from urllib.request import urlopen

# for extracting masks from JSON exports
def parseJSON(filename):
    with open(filename) as file:
        data = file.read()
        print(type(data))
        # we use json loads to be able to parse data
        decoded_data = json.loads(data)
        print(type(decoded_data))
        # res := list containing all instanceURIs
        res = []
        num_labels = len(decoded_data)
        for i in range(num_labels):
            object_data = decoded_data[i]['Label']['objects']
            print(type(decoded_data[i]))
            print(decoded_data[i])

            for j in range(len(object_data)):
                res.append(object_data[j]['instanceURI'])

        return res

# for extracting masks from CSV exports
def parseCSV(filename):
    mask_list = []

    with open(filename, 'r') as file:
        readCSV = csv.reader(file, delimiter=',')
        for row in readCSV:
            # mask URLs are stored in column 17
            tokenized = row[17].split(":")
            if len(tokenized) == 3:
                mask_URL = tokenized[1] + ":" + tokenized[2][:-1]
                mask_list.append(mask_URL[1:-1])
    return mask_list

# opens all exported data images. use with caution
def readAllImageData(image_data):
    for url in image_data:
        response = requests.get(url)
        img = Image.open(urlopen(url))
        img.show()

def downloadData(url_list):
    # creating a LabelboxData folder in user's local machine's download directory
    download_path = os.path.expanduser("~") + "/Downloads/LabelboxData/"
    print(url_list)
    if not os.path.exists(download_path):
        os.makedirs(download_path)

    print("Beginning download for Labelbox exported data...")

    for i in range(len(url_list)):
        # generating unique image names
        # Format: LabelID_Class_mask1.jpg
        file_name = download_path + url_list[i][0] + "_" + url_list[i][1] + "_mask" + str(i) + ".png"
        print(file_name)
        urllib.request.urlretrieve(url_list[i], file_name)

if __name__ == '__main__':
    # to run: python3 download_masks.py <FILENAME>

    exported_data = parseJSON(sys.argv[1])
    # exported_data = parseCSV(sys.argv[1])
    downloadData(exported_data)

# %%
# make sure that the exported JSON file and this script are in the same directory
# replace filename with appropriate
from PIL import Image
import requests, urllib, json, os, csv, sys
from urllib.request import urlopen

# for extracting masks from JSON exports
def parseJSON(mask104):
    with open(r'E:\THI MASTERS\Semestre1\Electives\Autonomous Vehicles by Machine Learning Algorithms\Project\New folder\keras-yolo3-master\dataset_mask\mask104.json') as file:
        data = file.read()
        print(type(data))
        # we use json loads to be able to parse data
        decoded_data = json.loads(data)
        print(type(decoded_data))
        # res := list containing all instanceURIs
        res = []
        num_labels = len(decoded_data)
        for i in range(num_labels):
            #object_data = decoded_data[i]['Label']['objects']
            #print(type(decoded_data[i]))
            #print(decoded_data[i])

            #for j in range(len(object_data)):
                #res.append(object_data[j]['instanceURI'])
            #object_data=decoded_data[i]
            #for j in range(len(object_data)):
                #res.append(object_data[j]['Labeled Data'])
            res.append(decoded_data[i]['Labeled Data'])
        return res

# for extracting masks from CSV exports
def parseCSV(mask104):
    mask_list = []

    with open(r'E:\THI MASTERS\Semestre1\Electives\Autonomous Vehicles by Machine Learning Algorithms\Project\New folder\keras-yolo3-master\dataset_mask\mask104.csv') as file:
        readCSV = csv.reader(file, delimiter=',')
        for row in readCSV:
            # mask URLs are stored in column 17
            tokenized = row[17].split(":")
            if len(tokenized) == 3:
                mask_URL = tokenized[1] + ":" + tokenized[2][:-1]
                mask_list.append(mask_URL[1:-1])
    return mask_list

# opens all exported data images. use with caution
def readAllImageData(image_data):
    for url in image_data:
        response = requests.get(url)
        img = Image.open(urlopen(url))
        img.show()

def downloadData(url_list):
    # creating a LabelboxData folder in user's local machine's download directory
    download_path = os.path.expanduser("~") + "/Downloads/LabelboxData1/"
    print(url_list)
    if not os.path.exists(download_path):
        os.makedirs(download_path)

    print("Beginning download for Labelbox exported data...")

    for i in range(len(url_list)):
        # generating unique image names
        # Format: LabelID_Class_mask1.jpg
        file_name = download_path + url_list[i][0] + "_" + url_list[i][1] + "_mask" + str(i) + ".png"
        print(file_name)
        urllib.request.urlretrieve(url_list[i], file_name)

if __name__ == '__main__':
    # to run: python3 download_masks.py <FILENAME>

    exported_data = parseJSON(sys.argv[1])
    #exported_data = parseCSV(sys.argv[1])
    downloadData(exported_data)
# Out:
# <class 'str'>
# <class 'list'>
# ['https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2Fc97fff59-59bc-2861-539f-2e6b485eada0-00000020.png?Expires=1595115345954&KeyName=labelbox-assets-key-1&Signature=GJLSuLIwR7ZhMn2wx--iPn_sPwE', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2F8245628b-4923-c27f-69ff-b052cf1a7e6c-00000052.png?Expires=1595115345955&KeyName=labelbox-assets-key-1&Signature=Fyg7yfJhGK8D5Ydh0z9diOGIKuE', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2Fe61ee3bc-c3bf-f032-910b-166916c66101-00000084.png?Expires=1595115345955&KeyName=labelbox-assets-key-1&Signature=MBgDEID6vGXU3dmXyRXNOPLsXVg', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2Fb9c92035-0c14-a823-0e22-5941102d5fb5-00000023.png?Expires=1595115345955&KeyName=labelbox-assets-key-1&Signature=m9de6dkeb3lwn75Ooi-Z5ozrW0g', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2Fa270fc9e-923b-fdb7-a39f-2d6300d47fdc-00000055.png?Expires=1595115345956&KeyName=labelbox-assets-key-1&Signature=32FE9PnsIEs05kcoQbnfO6hQ-Pw', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2F1407ef4d-6cb2-de95-50f4-a7f90c1045cf-00000087.png?Expires=1595115345956&KeyName=labelbox-assets-key-1&Signature=wcjqVCxC1LIGYcMC4zLQVxNZz5U', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2Fd8b2ecc2-fa8b-b0b9-fdb6-43a6ba0cccc5-00000026.png?Expires=1595115345956&KeyName=labelbox-assets-key-1&Signature=TF6s2O5Q7H5_REpYwViJbanc420', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2Fc0700ba7-c96e-5c06-358c-07c7f3e3d4f3-00000058.png?Expires=1595115345956&KeyName=labelbox-assets-key-1&Signature=jyYspW5TChvKLQEqA6Bdf1ePGSI', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2Fa83f02e7-34fd-c9c5-0e44-d8f96d3a6bbf-00000090.png?Expires=1595115345957&KeyName=labelbox-assets-key-1&Signature=kK2fhWxLyz2lLk-I0tynsdIXKgc', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2F7fd5078c-14c2-b3f3-7b31-155d79c2cdff-00000029.png?Expires=1595115345957&KeyName=labelbox-assets-key-1&Signature=7usnKPX58E1iOMht78kg9IJgtGo', 'https://storage.labelbox.com/ckbz1f3fcx3k1079466sw3v84%2F1513db3b-4023-04e0-5c